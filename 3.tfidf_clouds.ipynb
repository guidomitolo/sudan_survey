# %%
import pandas as pd
import re
import nltk

import matplotlib.pyplot as plt

from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer

# %% [markdown]
# ## Load Tokens

# %%
activities = pd.read_csv('./data/tokens/activities_tokens.csv')

# %%
health = pd.read_csv('./data/tokens/health_tokens.csv')

# %%
home_safety = pd.read_csv('./data/tokens/home_safety_tokens.csv')

# %%
quantity_learning = pd.read_csv('./data/tokens/quantity_learning_tokens.csv')

# %%
radio_lessons = pd.read_csv('./data/tokens/radio_lessons_tokens.csv')

# %%
radio_likes = pd.read_csv('./data/tokens/radio_likes_tokens.csv')

# %%
school_safety = pd.read_csv('./data/tokens/school_safety_tokens.csv')

# %%
school_safety_b = pd.read_csv('./data/tokens/school_safety_b_tokens.csv')

# %%
schoolwork = pd.read_csv('./data/tokens/schoolwork_tokens.csv')

# %%
learning_mat = pd.read_csv('./data/tokens/learning_mat_tokens.csv')

# %%
radio_school = pd.read_csv('./data/tokens/radio_school_tokens.csv')

# %% [markdown]
# ## Score vectorization

# %%
def tfidf_vectorization(df):
    df.drop('Unnamed: 0', axis=1, inplace=True)
    tfidf = TfidfTransformer().fit_transform(df)
    return pd.DataFrame(tfidf.todense(), columns = df.columns)

# %% [markdown]
# ## Visualization

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %% [markdown]
# #### 1. Are you doing other things at home to learn, aside from radio lessons? What are you doing?

# %%
activities_tfidf = tfidf_vectorization(activities)

# %%
lista = [activities, activities_tfidf]
title = ['Counter','Tf-Idf']

# %%
plt.rcParams['figure.figsize'] = [20 , 35]

# %%
for i, tokens in enumerate(lista):
    cloud = WordCloud(background_color='white')
    cloud.generate_from_frequencies(tokens.sum().sort_values())
    plt.subplot(1, 2, i + 1)
    plt.title(title[i])
    plt.imshow(cloud)
    plt.axis('off')
    
plt.show()

# %% [markdown]
# #### 2. Do you feel worried about your health due to studying/being at home during COVID-19? Why or why not?

# %%
health_tfidf = tfidf_vectorization(health)

# %%
lista = [health, health_tfidf]
title = ['Counter','Tf-Idf']

# %%
plt.rcParams['figure.figsize'] = [20 , 35]

# %%
for i, tokens in enumerate(lista):
    cloud = WordCloud(background_color='white')
    cloud.generate_from_frequencies(tokens.sum().sort_values())
    plt.subplot(1, 2, i + 1)
    plt.title(title[i])
    plt.imshow(cloud)
    plt.axis('off')
    
plt.show()

# %% [markdown]
# #### 3. Do you feel worried about your safety due to being at home during COVID-19? Why or why not?

# %%
home_safety_tfidf = tfidf_vectorization(home_safety)

# %%
lista = [home_safety, home_safety_tfidf]
title = ['Counter','Tf-Idf']

# %%
plt.rcParams['figure.figsize'] = [20 , 35]

# %%
for i, tokens in enumerate(lista):
    cloud = WordCloud(background_color='white')
    cloud.generate_from_frequencies(tokens.sum().sort_values())
    plt.subplot(1, 2, i + 1)
    plt.title(title[i])
    plt.imshow(cloud)
    plt.axis('off')
    
plt.show()

# %% [markdown]
# #### 4. Are you/your learners learning more or are you learning less using radio lessons since the COVID-19 school closures? Why

# %%
quantity_learning_tfidf = tfidf_vectorization(quantity_learning)

# %%
lista = [quantity_learning, quantity_learning_tfidf]
title = ['Counter','Tf-Idf']

# %%
plt.rcParams['figure.figsize'] = [20 , 35]

# %%
for i, tokens in enumerate(lista):
    cloud = WordCloud(background_color='white')
    cloud.generate_from_frequencies(tokens.sum().sort_values())
    plt.subplot(1, 2, i + 1)
    plt.title(title[i])
    plt.imshow(cloud)
    plt.axis('off')
    
plt.show()

# %% [markdown]
# #### 5. What is the quality of the radio lessons? How can the radio lessons be improved?

# %%
radio_lessons_tfidf = tfidf_vectorization(radio_lessons)

# %%
lista = [radio_lessons, radio_lessons_tfidf]
title = ['Counter','Tf-Idf']

# %%
plt.rcParams['figure.figsize'] = [20 , 35]

# %%
for i, tokens in enumerate(lista):
    cloud = WordCloud(background_color='white')
    cloud.generate_from_frequencies(tokens.sum().sort_values())
    plt.subplot(1, 2, i + 1)
    plt.title(title[i])
    plt.imshow(cloud)
    plt.axis('off')
    
plt.show()

# %% [markdown]
# #### 6. What do you like most about the radio lessons? What are the challenges with learning on the radio?

# %%
radio_likes_tfidf = tfidf_vectorization(radio_likes)

# %%
lista = [radio_likes, radio_likes_tfidf]
title = ['Counter','Tf-Idf']

# %%
plt.rcParams['figure.figsize'] = [20 , 35]

# %%
for i, tokens in enumerate(lista):
    cloud = WordCloud(background_color='white')
    cloud.generate_from_frequencies(tokens.sum().sort_values())
    plt.subplot(1, 2, i + 1)
    plt.title(title[i])
    plt.imshow(cloud)
    plt.axis('off')
    
plt.show()

# %% [markdown]
# #### 7.a. When schools re-open, do you think your school will have measures in place to ensure a safe learning environment? Why or why not?

# %%
school_safety_tfidf = tfidf_vectorization(school_safety)

# %%
lista = [school_safety, school_safety_tfidf]
title = ['Counter','Tf-Idf']

# %%
plt.rcParams['figure.figsize'] = [20 , 35]

# %%
for i, tokens in enumerate(lista):
    cloud = WordCloud(background_color='white')
    cloud.generate_from_frequencies(tokens.sum().sort_values())
    plt.subplot(1, 2, i + 1)
    plt.title(title[i])
    plt.imshow(cloud)
    plt.axis('off')
    
plt.show()

# %% [markdown]
# #### 7.b. What are your concerns about returning to school?

# %%
school_safety_b_tfidf = tfidf_vectorization(school_safety_b)

# %%
lista = [school_safety_b, school_safety_b_tfidf]
title = ['Counter','Tf-Idf']

# %%
plt.rcParams['figure.figsize'] = [20 , 35]

# %%
for i, tokens in enumerate(lista):
    cloud = WordCloud(background_color='white')
    cloud.generate_from_frequencies(tokens.sum().sort_values())
    plt.subplot(1, 2, i + 1)
    plt.title(title[i])
    plt.imshow(cloud)
    plt.axis('off')
    
plt.show()

# %% [markdown]
# #### 8. Are you/your learners doing more schoolwork or less schoolwork since the COVID-19 school closures? Why?

# %%
schoolwork_tfidf = tfidf_vectorization(schoolwork)

# %%
lista = [schoolwork, schoolwork_tfidf]
title = ['Counter','Tf-Idf']

# %%
plt.rcParams['figure.figsize'] = [20 , 35]

# %%
for i, tokens in enumerate(lista):
    cloud = WordCloud(background_color='white')
    cloud.generate_from_frequencies(tokens.sum().sort_values())
    plt.subplot(1, 2, i + 1)
    plt.title(title[i])
    plt.imshow(cloud)
    plt.axis('off')
    
plt.show()

# %% [markdown]
# #### 9. When schools reopen, would you still listen to radio lessons? Why or why not?

# %%
learning_mat_tfidf = tfidf_vectorization(learning_mat)

# %%
lista = [learning_mat, learning_mat_tfidf]
title = ['Counter','Tf-Idf']

# %%
plt.rcParams['figure.figsize'] = [20 , 35]

# %%
for i, tokens in enumerate(lista):
    cloud = WordCloud(background_color='white')
    cloud.generate_from_frequencies(tokens.sum().sort_values())
    plt.subplot(1, 2, i + 1)
    plt.title(title[i])
    plt.imshow(cloud)
    plt.axis('off')
    
plt.show()

# %% [markdown]
# #### 10. What materials are you using? How often do you use these materials? Do you find these materials more or less helpful than radio lessons? Why?

# %%
radio_school_tfidf = tfidf_vectorization(radio_school)

# %%
lista = [radio_school, radio_school_tfidf]
title = ['Counter','Tf-Idf']

# %%
plt.rcParams['figure.figsize'] = [20 , 35]

# %%
for i, tokens in enumerate(lista):
    cloud = WordCloud(background_color='white')
    cloud.generate_from_frequencies(tokens.sum().sort_values())
    plt.subplot(1, 2, i + 1)
    plt.title(title[i])
    plt.imshow(cloud)
    plt.axis('off')
    
plt.show()
